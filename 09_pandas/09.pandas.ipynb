# %% [markdown]
# # La vida del CSV 📜

# %% [markdown]
# ### Leer:
#
# https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html

# %%
import pandas as pd
import json
import numpy as np

# %%
brew = pd.read_csv("breweries_us.csv")

# %%
from string import ascii_lowercase
import random

def random_string():
    
    return "".join([random.choice(ascii_lowercase) for _ in range(random.randint(10,15))])

# %%
random_string()
# Out:
# 'hkaugxjxtdd'

# %%
brew
# Out:
#                                      brewery_name             type  \
# 0                              Valley Brewing Co.          Brewpub
# 1                              Valley Brewing Co.          Brewpub
# 2                               Valley Brewing Co     Microbrewery
# 3                           Ukiah Brewing Company          Brewpub
# 4                              Tustin Brewing Co.          Brewpub
# ...                                           ...              ...
# 2402  Capitol City Brewing Company (Capitol Hill)          Brewpub
# 2403                 Capitol City Brewing Company          Brewpub
# 2404                           Old Harbor Brewery          Brewpub
# 2405                       Isla Verde Brewing Co.     Microbrewery
# 2406                         Cerveceria India Inc  RegionalBrewery
#
#                                                 address  \
# 0              PO Box 4653, Stockton, California, 95204
# 1            157 Adams St., Stockton, California, 95204
# 2          1950 W Freemont, Stockton, California, 95203
# 3            102 S. State St., Ukiah, California, 95482
# 4     13011 Newport Ave. #100, Tustin, California, 9...
# ...                                                 ...
# 2402  2 Massachusetts Ave., Washington, DC, Washingt...
# 2403  1100 New York Ave. NW, Washington, DC, Washing...
# 2404  Gen del Valle 1021 Urb Delicias, San Juan, PR,...
# 2405  Condiminum Torrimar Plaza # 14B, Guaynabo , PR...
# 2406                     PO Box 1690, Mayaguez, PR, 681
#
#                                                 website          state  \
# 0                            http://www.valleybrew.com/     california
# 1                            http://www.valleybrew.com/     california
# 2                            http://www.valleybrew.com/     california
# 3                        http://www.ukiahbrewingco.com/     california
# 4                         http://www.tustinbrewery.com/     california
# ...                                                 ...            ...
# 2402                        http://www.capcitybrew.com/  washington-dc
# 2403                        http://www.capcitybrew.com/  washington-dc
# 2404                       http://oldharborbrewery.com/    puerto-rico
# 2405                                                ...    puerto-rico
# 2406                                                ...    puerto-rico
#
#       state_breweries
# 0                 284
# 1                 284
# 2                 284
# 3                 284
# 4                 284
# ...               ...
# 2402                9
# 2403                9
# 2404                3
# 2405                3
# 2406                3
#
# [2407 rows x 6 columns]

# %%
brew["numero_aleatorio"] = "jajajaja"

# %%
brew.query("state_breweries > 150")

# %%
brew[
    (brew["address"].str.lower().str.contains("plaza"))
    & (brew["website"].str.lower().str.contains("com"))
    & (brew["state_breweries"] > 100)
]
# Out:
#                                     brewery_name          type  \
# 584   C.B. and Potts/Big Horn Brewery- Englewood       Brewpub
# 599                             Big Horn Brewery       Brewpub
# 1442       John Harvards Brew House - Lake Grove       Brewpub
# 1464                         Defiant Brewing Co.  Microbrewery
#
#                                                 address  \
# 584   6575 Greenwood Plaza Blvd., Englewood, Colorad...
# 599   6575 Greenwood Plaza Blvd., Englewood, Colorad...
# 1442  2093 Smith Haven Plaza, Lake Grove, New York, ...
# 1464     6 E Dexter Plaza, Pearl River, New York, 10965
#
#                              website     state  state_breweries  \
# 584          http://www.cbpotts.com/  colorado              182
# 599           http://www.theram.com/  colorado              182
# 1442    http://www.johnharvards.com/  new-york              107
# 1464  http://www.defiantbrewing.com/  new-york              107
#
#      numero_aleatorio
# 584          jajajaja
# 599          jajajaja
# 1442         jajajaja
# 1464         jajajaja

# %%
brew.loc[1464]
# Out:
# brewery_name                                   Defiant Brewing Co.
# type                                                  Microbrewery
# address             6 E Dexter Plaza, Pearl River, New York, 10965
# website                             http://www.defiantbrewing.com/
# state                                                     new-york
# state_breweries                                                107
# numero_aleatorio                                          jajajaja
# Name: 1464, dtype: object

# %%
brew.loc[brew["state_breweries"] > 100, "state"]
# Out:
# 0       california
# 1       california
# 2       california
# 3       california
# 4       california
#            ...
# 2308    washington
# 2309    washington
# 2310    washington
# 2311    washington
# 2312    washington
# Name: state, Length: 987, dtype: object

# %%
json.loads(brew.to_json(orient="index"))
# Out:
# {'0': {'brewery_name': 'Valley Brewing Co.',
#   'type': 'Brewpub',
#   'address': 'PO Box 4653, Stockton, California, 95204',
#   'website': 'http://www.valleybrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '1': {'brewery_name': 'Valley Brewing Co.',
#   'type': 'Brewpub',
#   'address': '157 Adams St., Stockton, California, 95204',
#   'website': 'http://www.valleybrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '2': {'brewery_name': 'Valley Brewing Co',
#   'type': 'Microbrewery',
#   'address': '1950 W Freemont, Stockton, California, 95203',
#   'website': 'http://www.valleybrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '3': {'brewery_name': 'Ukiah Brewing Company',
#   'type': 'Brewpub',
#   'address': '102 S. State St., Ukiah, California, 95482',
#   'website': 'http://www.ukiahbrewingco.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '4': {'brewery_name': 'Tustin Brewing Co.',
#   'type': 'Brewpub',
#   'address': '13011 Newport Ave. #100, Tustin, California, 92780',
#   'website': 'http://www.tustinbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '5': {'brewery_name': 'Trumer Brauerei',
#   'type': 'Microbrewery',
#   'address': '1404 4th St., Berkeley, California, 94608',
#   'website': 'http://www.trumer-international.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '6': {'brewery_name': 'Trumer Brauerei',
#   'type': 'RegionalBrewery',
#   'address': '1404 Fourth St., Berkeley, California, 94710',
#   'website': 'http://www.trumer-international.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '7': {'brewery_name': 'Triple Rock Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1920 Shattuck Ave, Berkeley, California, 94704',
#   'website': 'http://www.triplerock.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '8': {'brewery_name': 'Tied House Cafe & Brewery (San Jose)',
#   'type': 'Brewpub',
#   'address': '65 N. San Pedro, San Jose, California, 95110',
#   'website': 'http://www.tiedhouse.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '9': {'brewery_name': 'Tied House Cafe & Brewery (Mt. View)',
#   'type': 'Brewpub',
#   'address': '954 Villa St., Mountain View, California, 94041',
#   'website': 'http://www.tiedhouse.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '10': {'brewery_name': 'Thirsty Bear Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '661 Howard St., San Francisco, California, 94105',
#   'website': 'http://thirstybear.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '11': {'brewery_name': 'Third Street Ale Works',
#   'type': 'Brewpub',
#   'address': '610 3rd St., Santa Rosa, California, 95404',
#   'website': 'http://www.thirdstreetaleworks.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '12': {'brewery_name': 'The Brewhouse',
#   'type': 'Brewpub',
#   'address': '229 W. Montecito, Santa Barbara, California, 93101',
#   'website': 'http://www.brewhousesb.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '13': {'brewery_name': 'The Beach Chalet',
#   'type': 'Brewpub',
#   'address': '1000 Great Highway, San Francisco, California, 94121',
#   'website': 'http://www.beachchalet.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '14': {'brewery_name': 'Telegraph Brewing Company',
#   'type': 'Microbrewery',
#   'address': '416 N. Salsipuedes St., Santa Barbara, California, 93103',
#   'website': 'http://www.telegraphbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '15': {'brewery_name': "Taylor's Restaurant & Brewery",
#   'type': 'Brewpub',
#   'address': '721 Grand Ave., San Diego, California, 92109',
#   'website': '                                                                            -                                                                    ',
#   'state': 'california',
#   'state_breweries': 284},
#  '16': {'brewery_name': 'Taps Fishouse & Brewery',
#   'type': 'Brewpub',
#   'address': '101 E. Imperial Hwy., Brea, California, 92821',
#   'website': 'http://www.tapsbrea.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '17': {'brewery_name': 'Tailgate Brewery, LLC',
#   'type': 'ContractBrewery',
#   'address': '6827 Airoso Ave, San Diego, California, 92120',
#   'website': 'http://tailgatebeer.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '18': {'brewery_name': 'Sudwerk Privatbrauerei Hübsch',
#   'type': 'Brewpub',
#   'address': '2001 2nd St., Davis, California, 95616',
#   'website': 'http://www.sudwerk.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '19': {'brewery_name': 'Sudwerk Brewery & Grill',
#   'type': 'Brewpub',
#   'address': '1375 Exposition Blvd., Sacramento, California, 95815',
#   'website': 'http://www.sudwerk.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '20': {'brewery_name': 'Stumptown Brewery',
#   'type': 'Microbrewery',
#   'address': '15045 River Rd., Guerneville, California, 95446',
#   'website': 'http://www.stumptown.com/brews/',
#   'state': 'california',
#   'state_breweries': 284},
#  '21': {'brewery_name': 'Stone Brewing/World Bistro & Gardens',
#   'type': 'RegionalBrewery',
#   'address': '1999 Citracado Pkwy., Escondido, California, 92029',
#   'website': 'https://www.stonebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '22': {'brewery_name': 'Steelhead Brewing Co - Burlingame',
#   'type': 'Brewpub',
#   'address': '333 California Dr, Burlingame, California, 94010',
#   'website': 'http://www.steelheadbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '23': {'brewery_name': 'Steelhead Brewery & Cafe',
#   'type': 'Brewpub',
#   'address': '4175 Campus Dr., Irvine, California, 92612',
#   'website': 'http://www.steelheadbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '24': {'brewery_name': 'Stadium Brewing Company',
#   'type': 'Brewpub',
#   'address': '26731 Aliso Creek Rd. Ste. C, Aliso Viejo, California, 92656',
#   'website': 'http://stadiumbrewing.com/index.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '25': {'brewery_name': "St. Stan's Brewing Co.",
#   'type': 'Brewpub',
#   'address': '821 L. Street, Modesto, California, 95354',
#   'website': 'http://ststans.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '26': {'brewery_name': 'Speakeasy Ales and Lagers',
#   'type': 'Microbrewery',
#   'address': '1195-A Evans Ave., San Francisco, California, 94124',
#   'website': 'http://www.goodbeer.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '27': {'brewery_name': 'Spanish Peaks Brewing Co. ',
#   'type': 'ContractBrewery',
#   'address': 'PO Box 820, King City, California, 93930',
#   'website': 'http://www.blackdogales.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '28': {'brewery_name': 'Sonoma Chicken & Brewery',
#   'type': 'Brewpub',
#   'address': '200 E. Campbell Ave., Campbell, California, 95008',
#   'website': 'http://www.sonomachickencoop.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '29': {'brewery_name': 'Solana Beach Brewery (Pizza Port)',
#   'type': 'Brewpub',
#   'address': '135 N. Highway 101, Solana Beach, California, 92075',
#   'website': 'http://www.pizzaport.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '30': {'brewery_name': 'Snowshoe Brewing Company',
#   'type': 'Brewpub',
#   'address': '19040 Standard Rd. , Sonora, California, 95370',
#   'website': 'http://www.snowshoebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '31': {'brewery_name': 'Snowshoe Brewing Company',
#   'type': 'Brewpub',
#   'address': '2050 Hwy. 4 , Arnold, California, 95223',
#   'website': 'http://www.snowshoebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '32': {'brewery_name': 'Snowshoe Brewing Co.',
#   'type': 'Brewpub',
#   'address': 'PO Box 2224, Arnold, California, 95223',
#   'website': 'http://www.snowshoebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '33': {'brewery_name': 'Skyscraper Brewing Company',
#   'type': 'Microbrewery',
#   'address': '3229 Durfee Ave., El Monte, California, 91732',
#   'website': 'http://www.skyscraperbrewing.com/home.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '34': {'brewery_name': 'Six Rivers Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1300 Central Ave., McKinleyville, California, 95519',
#   'website': 'http://www.sixriversbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '35': {'brewery_name': 'Silverado Brewing Company',
#   'type': 'Brewpub',
#   'address': '3020 n St. Helena Hwy. Ste. A, St. Helena, California, 94574',
#   'website': 'http://www.silveradobrewingcompany.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '36': {'brewery_name': 'Sierra Nevada Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1075 E. 20th St., Chico, California, 95928',
#   'website': 'http://www.sierranevada.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '37': {'brewery_name': 'Sierra Madre Brewing Co.',
#   'type': 'ContractBrewery',
#   'address': '21 Kersting Court, Sierra Madre, California, 91024',
#   'website': 'http://www.sierramadrenews.net/smbc/index.htm',
#   'state': 'california',
#   'state_breweries': 284},
#  '38': {'brewery_name': 'Shmaltz Brewing Co',
#   'type': 'ContractBrewery',
#   'address': '912 Cole Street, #338, San Francisco, California, 94117',
#   'website': 'http://shmaltzbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '39': {'brewery_name': 'Sequoia Brewing Company',
#   'type': 'Brewpub',
#   'address': '777 East Olive Ave., Fresno, California, 93728',
#   'website': 'http://sequoiabrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '40': {'brewery_name': 'Sequoia Brewing Company',
#   'type': 'MultitapBar',
#   'address': '1188 E. Champlain Dr., Fresno, California, 93728',
#   'website': 'http://sequoiabrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '41': {'brewery_name': 'Seabright Brewery',
#   'type': 'Brewpub',
#   'address': '519 Seabright Ave. Suite 107, Santa Cruz, California, 95062',
#   'website': 'http://www.seabrightbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '42': {'brewery_name': 'Schooners Grille & Brewery',
#   'type': 'Brewpub',
#   'address': '4250 Lone Tree Way, Antioch, California, 94509',
#   'website': 'http://www.schoonersbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '43': {'brewery_name': 'Santa Cruz Mountain Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '402 Ingalls St. #27, Santa Cruz, California, 95060',
#   'website': 'http://www.santacruzmountainbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '44': {'brewery_name': 'Santa Cruz Aleworks',
#   'type': 'Microbrewery',
#   'address': '150 Dubois St. , Santa Cruz, California, 95060',
#   'website': 'http://www.santacruzaleworks.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '45': {'brewery_name': 'Santa Barbara Brewing Co.',
#   'type': 'Brewpub',
#   'address': '501 State St., Santa Barbara, California, 93101',
#   'website': 'http://www.sbbrewco.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '46': {'brewery_name': 'San Pedro Brewing Company',
#   'type': 'Brewpub',
#   'address': '331 W. 6th St., San Pedro, California, 90731',
#   'website': 'http://www.sanpedrobrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '47': {'brewery_name': 'San Marcos Brewery & Grill',
#   'type': 'Brewpub',
#   'address': '1080 W. Old San Marcos Blvd., San Marcos, California, 92069',
#   'website': 'http://www.sanmarcosbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '48': {'brewery_name': 'San Francisco Brewing Co.',
#   'type': 'Brewpub',
#   'address': '155 Columbus Ave., San Francisco, California, 94133',
#   'website': 'http://www.sfbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '49': {'brewery_name': 'San Diego Brewing Company',
#   'type': 'Brewpub',
#   'address': "10450 Friar's Road - Suite L, San Diego, California, 92120",
#   'website': 'http://www.sandiegobrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '50': {'brewery_name': "Ruth McGowan's Brewpub",
#   'type': 'Brewpub',
#   'address': '131 E. 1st St., Cloverdale, California, 95425',
#   'website': 'http://www.ruthmcgowansbrewpub.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '51': {'brewery_name': 'Russian River Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '725 4th Street, Santa Rosa, California, 95404',
#   'website': 'http://www.russianriverbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '52': {'brewery_name': 'Rubicon Brewing Company',
#   'type': 'Brewpub',
#   'address': '2004 Capital Ave., Sacramento, California, 95814',
#   'website': 'http://www.rubiconbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '53': {'brewery_name': 'Rogue Ales Public House',
#   'type': 'Brewpub',
#   'address': '673 Union St. (@ Powell), San Francisco, California, 94133',
#   'website': 'http://rogue.com/index.php',
#   'state': 'california',
#   'state_breweries': 284},
#  '54': {'brewery_name': 'Rock Bottom Restaurant & Brewery',
#   'type': 'Brewpub',
#   'address': '1875 S. Bascom Ave. #700, Campbell, California, 95008',
#   'website': 'http://www.rockbottom.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '55': {'brewery_name': 'Rock Bottom Restaurant & Brewery',
#   'type': 'Brewpub',
#   'address': '8980 Villa La Jolla Dr., La Jolla, California, 92037',
#   'website': 'http://www.rockbottom.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '56': {'brewery_name': 'Rock Bottom Restaurant & Brewery',
#   'type': 'Brewpub',
#   'address': '401 G Street, San Diego, California, 92101',
#   'website': 'http://www.rockbottom.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '57': {'brewery_name': 'Rock Bottom Restaurant & Brewery',
#   'type': 'Brewpub',
#   'address': '1 Pine Ave., Long Beach, California, 90802',
#   'website': 'http://www.rockbottom.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '58': {'brewery_name': 'Riverside Brewing Co.',
#   'type': 'Brewpub-Closed',
#   'address': '3397 7th St., Riverside, California, 92501',
#   'website': 'http://www.facebook.com/pages/Riverside-Brewing-Co/51553507625',
#   'state': 'california',
#   'state_breweries': 284},
#  '59': {'brewery_name': 'River City Brewing',
#   'type': 'Brewpub',
#   'address': '545 Downtown Plaza, Ste. 1115 , Sacramento, California, 95814',
#   'website': 'http://www.rivercitybrewing.net/',
#   'state': 'california',
#   'state_breweries': 284},
#  '60': {'brewery_name': 'Revolutionary Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '31872 Marcasite Ln, Castaic, California, 91384',
#   'website': 'http://revbrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '61': {'brewery_name': 'Redondo Beach Brewing Company',
#   'type': 'Brewpub',
#   'address': '1814 S. Catalina Ave., Redondo Beach, California, 90277',
#   'website': 'http://www.redondobeachbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '62': {'brewery_name': 'Red Rock Winery & Brewery',
#   'type': 'Microbrewery',
#   'address': '7326 East Hwy 140, Merced, California, 95340',
#   'website': 'http://www.redrockwinery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '63': {'brewery_name': 'Red Car Brewery & Restaurant',
#   'type': 'Brewpub',
#   'address': '1266 Sartori Ave., Torrance, California, 90501',
#   'website': 'http://www.redcarbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '64': {'brewery_name': 'Reaper Ale',
#   'type': 'ContractBrewery',
#   'address': '26741 Portola Pkwy, Foothill Ranch, California, 92610',
#   'website': 'http://www.reaperale.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '65': {'brewery_name': 'Pyramid Brewery & Alehouse',
#   'type': 'Brewpub',
#   'address': '901 Gilman St., Berkeley, California, 94710',
#   'website': 'http://www.pyramidbrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '66': {'brewery_name': 'Pyramid Alehouse Brewery & Restaurant',
#   'type': 'Brewpub',
#   'address': '1410 Locust Street, Walnut Creek, California, 94596',
#   'website': 'http://www.pyramidbrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '67': {'brewery_name': 'Pyramid Alehouse',
#   'type': 'Brewpub',
#   'address': '1029 K St., Sacramento, California, 95814',
#   'website': 'http://www.pyramidbrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '68': {'brewery_name': 'Pyramid Alehouse',
#   'type': 'RegionalBrewery',
#   'address': '901 Gilman St, Berkeley, California, 94710',
#   'website': 'http://www.pyramidbrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '69': {'brewery_name': 'Port Brewing Co/The Lost Abbey',
#   'type': 'Microbrewery',
#   'address': '155 Mata Way #104, San Marcos, California, 92069',
#   'website': 'http://www.pizzaport.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '70': {'brewery_name': 'Pizza Port Carlsbad Brewery',
#   'type': 'Brewpub',
#   'address': '571 Carlsbad Village Dr., Carlsbad, California, 92008',
#   'website': 'http://www.pizzaport.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '71': {'brewery_name': 'Pizza Port Brewing Co-Solana Beach',
#   'type': 'Brewpub',
#   'address': '135 n hwy 101, Solana Beach, California, 92075',
#   'website': 'http://www.pizzaport.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '72': {'brewery_name': 'Pizza Port Brewing Company',
#   'type': 'Brewpub',
#   'address': '301 N. El Camino Real, San Clemente, California, 92672',
#   'website': 'http://www.pizzaport.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '73': {'brewery_name': "Peter B's Brewpub",
#   'type': 'Brewpub',
#   'address': '2 Portola Place, Monterey, California, 93940',
#   'website': 'http://www.portolahotel.com/dining/brewpub',
#   'state': 'california',
#   'state_breweries': 284},
#  '74': {'brewery_name': 'Pacific Coast Brewing Co.',
#   'type': 'Brewpub',
#   'address': '906 Washington St., Oakland, California, 94607',
#   'website': 'http://www.pacificcoastbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '75': {'brewery_name': "Omaha Jack's Steakhouse & Brewery",
#   'type': 'Brewpub',
#   'address': '11837 Foothill Blvd., Ste A., Rancho Cucamonga, California, 91730',
#   'website': 'http://www.omahajacks.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '76': {'brewery_name': "Oggi's Pizza & Brewing Company (Carmel Mtn. Ranch)",
#   'type': 'Brewpub',
#   'address': '10155 Rancho Carmel Dr., San Diego, California, 92123',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '77': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '23641 Via Linda, Mission Viejo, California, 92691',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '78': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '305 Encinitas Blvd., Encinitas, California, 92024',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '79': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '425 S. Melrose Dr., Vista, California, 92083',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '80': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '41301 Margarita Dr., Temecula, California, 92591',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '81': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '9828 Mission Gorge Rd., Santee, California, 92071',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '82': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '18810 Soledad Canyon Rd., Santa Clarita, California, 91351',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '83': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '1500 East Village Way, Orange, California, 92865',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '84': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '2245 Fenton Pkwy. #108, San Diego, California, 92108',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '85': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '19461 Main St., Huntington Beach, California, 92648',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '86': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '200 E. Via Rancho Pkwy. Suite 201, Escondido, California, 92025',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '87': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '12840 Carmel Country Rd., Del Mar, California, 92130',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '88': {'brewery_name': "Oggi's Pizza & Brewing Company",
#   'type': 'Brewpub',
#   'address': '2363 California Ave. #105, Corona, California, 92881',
#   'website': 'http://www.oggis.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '89': {'brewery_name': 'Oceanside Ale Works',
#   'type': 'Microbrewery',
#   'address': '3800 Oceanic Dr., Oceanside, California, 92056',
#   'website': 'http://www.oceansidealeworks.net/',
#   'state': 'california',
#   'state_breweries': 284},
#  '90': {'brewery_name': 'Ocean Brewing Company',
#   'type': 'Brewpub',
#   'address': '237 Ocean Ave., Laguna Beach, California, 92651',
#   'website': 'http://www.facebook.com/oceanavelb',
#   'state': 'california',
#   'state_breweries': 284},
#  '91': {'brewery_name': 'North Coast Brewing Co.',
#   'type': 'RegionalBrewery',
#   'address': '455 N. Main St., Fort Bragg, California, 95437',
#   'website': 'http://www.northcoastbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '92': {'brewery_name': 'Newport Beach Brewing Co.',
#   'type': 'Brewpub',
#   'address': '2920 Newport Blvd., Newport Beach, California, 92663',
#   'website': 'http://www.newportbeachbrewingcompany.com',
#   'state': 'california',
#   'state_breweries': 284},
#  '93': {'brewery_name': 'New English Brewing Co. Inc',
#   'type': 'Microbrewery',
#   'address': '10755-F Scripps Poway Pkwy, #205, San Diego, California, 92131',
#   'website': 'http://www.newenglishbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '94': {'brewery_name': 'Napa Valley Brewing Co./ Calistoga Inn',
#   'type': 'Brewpub',
#   'address': '1250 Lincoln Ave., Calistoga, California, 94515',
#   'website': 'http://www.napabeer.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '95': {'brewery_name': 'Mt. Shasta Brewing Company',
#   'type': 'Microbrewery',
#   'address': '360 College Ave., Weed, California, 96094',
#   'website': 'http://www.weedales.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '96': {'brewery_name': "Moylan's Brewery & Restaurant",
#   'type': 'Brewpub',
#   'address': '15 Rowland Way, Novato, California, 94945',
#   'website': 'http://www.moylans.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '97': {'brewery_name': 'Mount Tallac Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '2060 Eloise Ave., S Lake Tahoe, California, 96150',
#   'website': 'https://www.facebook.com/pages/Mt-Tallac-Brewing-Company/120321407995293',
#   'state': 'california',
#   'state_breweries': 284},
#  '98': {'brewery_name': 'Mount St. Helena Brewing Co.',
#   'type': 'Brewpub',
#   'address': '21167 Calistoga St., Middletown, California, 95461',
#   'website': 'http://sainthelenabrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '99': {'brewery_name': 'Morro Bay Brewing Company',
#   'type': 'Brewpub',
#   'address': '280 Harbor St., Morro Bay, California, 93442',
#   'website': '                                                                            -                                                                    ',
#   'state': 'california',
#   'state_breweries': 284},
#  '100': {'brewery_name': 'Moonlight Brewing Company',
#   'type': 'Microbrewery',
#   'address': 'P.O. Box 316, Fulton, California, 95439',
#   'website': 'http://www.moonlightbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '101': {'brewery_name': 'Mission Brewery @ Miami Grill',
#   'type': 'Brewpub',
#   'address': '4353 La Jolla Village Dr, San Diego, California, 92122',
#   'website': 'http://www.miamigrille.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '102': {'brewery_name': 'Miller Brewing Company',
#   'type': 'Brewpub',
#   'address': '15801 E. 1st St. , Irwindale, California, 91706',
#   'website': 'http://www.millercoors.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '103': {'brewery_name': 'Mendocino Brewing Co.',
#   'type': 'RegionalBrewery',
#   'address': '1600 Airport Rd, Ukiah, California, 95482',
#   'website': 'http://mendobrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '104': {'brewery_name': 'Mendocino Brewing Co.',
#   'type': 'Brewpub',
#   'address': '13351 Hwy. 101 S., Hopland, California, 95449',
#   'website': 'http://mendobrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '105': {'brewery_name': "Mary's Pizza Shack",
#   'type': 'Brewpub',
#   'address': '711 Pleasant Grove Blvd, Roseville, California, 95661',
#   'website': 'http://www.maryspizzashack.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '106': {'brewery_name': 'Marin Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1809 Larkspur Landing Circle, Larkspur, California, 94939',
#   'website': 'http://www.marinbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '107': {'brewery_name': 'Marauder Brewing, Inc',
#   'type': 'Microbrewery',
#   'address': '10737 Meadow Glen Way E, Escondido, California, 92026',
#   'website': 'http://www.marauderbeer.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '108': {'brewery_name': 'Mammoth Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '18 Main St., Mammoth Lakes, California, 93546',
#   'website': 'http://www.mammothbrewingco.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '109': {'brewery_name': 'Main Street Brewery/Lamppost Pizza',
#   'type': 'Brewpub',
#   'address': '300 N Main St., Corona, California, 92882',
#   'website': 'http://www.mainstreetbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '110': {'brewery_name': 'Main Street Brewery',
#   'type': 'Brewpub',
#   'address': '830 Main St., Pleasanton, California, 94566',
#   'website': 'http://www.mainstbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '111': {'brewery_name': 'Magnolia Pub & Brewery',
#   'type': 'Brewpub',
#   'address': '1398 Haight St., San Francisco, California, 94117',
#   'website': 'http://www.magnoliapub.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '112': {'brewery_name': 'Mad River Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '195 Taylor Way, Blue Lake, California, 95525',
#   'website': 'http://www.madriverbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '113': {'brewery_name': 'Lost Coast Brewery',
#   'type': 'Microbrewery',
#   'address': '123 W 3rd St, Eureka, California, 95501',
#   'website': 'http://www.lostcoast.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '114': {'brewery_name': 'Los Gatos Brewing Company',
#   'type': 'Brewpub',
#   'address': '130-G N. Santa Cruz Ave., Los Gatos, California, 95030',
#   'website': 'http://lgbrewingco.com/index.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '115': {'brewery_name': 'Lodi Beer Company',
#   'type': 'Brewpub',
#   'address': '105 School St., Lodi, California, 95240',
#   'website': 'http://www.lodibeercompany.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '116': {'brewery_name': 'Lockdown Brewing Company',
#   'type': 'ContractBrewery',
#   'address': '317 Leidesdorf St., Folsom, California, 95630',
#   'website': 'http://www.lockdownbrewingcompany.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '117': {'brewery_name': 'Linden Street Brewery',
#   'type': 'Mircobrewery',
#   'address': '95 Linden St. Ste. 8, Oakland, California, 94607',
#   'website': 'http://www.lindenbeer.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '118': {'brewery_name': 'Lightning Brewery',
#   'type': 'Microbrewery',
#   'address': '13200 Kirkham Way #105, Poway, California, 92064',
#   'website': 'http://www.lightningbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '119': {'brewery_name': 'Library Alehouse',
#   'type': 'MultitapBar',
#   'address': '2911 Main St., Santa Monica, California, 90405',
#   'website': 'http://www.libraryalehouse.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '120': {'brewery_name': 'Lengthwise Brewing Co.',
#   'type': 'Brewpub',
#   'address': '6720 Schirra Ct., Bakersfield, California, 93313',
#   'website': 'http://www.lengthwise.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '121': {'brewery_name': 'Left Coast Brewing Company',
#   'type': 'Brewpub',
#   'address': '1245 Puerto del Sol, San Clemente, California, 92673',
#   'website': 'http://www.leftcoastbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '122': {'brewery_name': 'Lagunitas Brewing Company',
#   'type': 'Microbrewery',
#   'address': '1322 Ross St., Petaluma, California, 94954',
#   'website': 'http://www.lagunitas.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '123': {'brewery_name': 'La Jolla Brewery',
#   'type': 'Brewpub',
#   'address': '4353 La Jolla Village Dr., La Jolla, California, 92037',
#   'website': 'http://www.lajollabrewhouse.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '124': {'brewery_name': 'La Jolla Brew House',
#   'type': 'Brewpub',
#   'address': '7536 Fay Ave., La Jolla, California, 92037',
#   'website': 'http://www.lajollabrewhouse.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '125': {'brewery_name': 'Karl Strauss Brewery Restaurant',
#   'type': 'Brewpub',
#   'address': '901-A S. Coast Dr., Costa Mesa, California, 92626',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '126': {'brewery_name': 'Karl Strauss Brewery Gardens',
#   'type': 'Microbrewery',
#   'address': '5985 Sante Fe St., San Diego, California, 92109',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '127': {'brewery_name': 'Karl Strauss Brewery Gardens',
#   'type': 'Brewpub',
#   'address': '9675 Scranton Rd., Sorrento Mesa, California, 92121',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '128': {'brewery_name': 'Karl Strauss Brewery & Restaurant',
#   'type': 'Brewpub',
#   'address': '1000 Universal Center Dr., Universal City, California, 91608',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '129': {'brewery_name': 'Karl Strauss Brewery & Restaurant',
#   'type': 'Brewpub',
#   'address': '5801 Armada Drive, Carlsbad, California, 92008',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '130': {'brewery_name': 'Karl Strauss Brewery & Grill',
#   'type': 'Brewpub',
#   'address': '1044 Wall St., La Jolla, California, 92037',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '131': {'brewery_name': 'Karl Strauss Brewery & Grill',
#   'type': 'Brewpub',
#   'address': '1157 Columbia St., San Diego, California, 92101',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '132': {'brewery_name': 'Karl Strauss Breweries',
#   'type': 'Brewpub-Closed',
#   'address': '2785 Kurtz, San Diego, California, 92110',
#   'website': 'http://www.karlstrauss.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '133': {'brewery_name': "JT Schmid's Brewhouse & Eatery",
#   'type': 'Brewpub',
#   'address': '1725 S Douglass Rd. Ste. C, Anaheim, California, 92806',
#   'website': 'http://www.jtschmids.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '134': {'brewery_name': 'Jergensen Brewing Company',
#   'type': 'Microbrewery',
#   'address': '11641 Rancho Road, Adelanto, California, 92301',
#   'website': 'http://imcsitefiles.com/jurgys/',
#   'state': 'california',
#   'state_breweries': 284},
#  '135': {'brewery_name': "Jack's Brewing Company",
#   'type': 'Brewpub',
#   'address': '39176 Argonaut Way, Fremont, California, 94538',
#   'website': 'http://www.jacksbrewingcompany.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '136': {'brewery_name': 'Jack Russell Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '2380 Larsen Dr., Camino, California, 95709',
#   'website': 'https://www.facebook.com/jackrussellfarmbrewery',
#   'state': 'california',
#   'state_breweries': 284},
#  '137': {'brewery_name': 'J.S. McNg Brewery Concern',
#   'type': 'Microbrewery',
#   'address': '3658 Monterey Blvd.`, Oakland, California, 94619',
#   'website': '                                                                            -                                                                    ',
#   'state': 'california',
#   'state_breweries': 284},
#  '138': {'brewery_name': 'Island Brewing Company',
#   'type': 'Microbrewery',
#   'address': '5049 Sixth St., Carpinteria, California, 93013',
#   'website': 'http://www.islandbrewingcompany.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '139': {'brewery_name': 'Iron Springs Pub & Brewery',
#   'type': 'Brewpub',
#   'address': '765-A Center Blvd., Fairfax, California, 94930',
#   'website': 'http://www.ironspringspub.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '140': {'brewery_name': 'Inland Empire Brewing Co.',
#   'type': 'Mircobrewery',
#   'address': '1710 Palmyrita Ave., Ste 11, Riverside, California, 92507',
#   'website': 'http://www.iebrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '141': {'brewery_name': 'Indian Wells Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '2565 N. Hwy. 14, Inyokern, California, 93527',
#   'website': 'http://www.mojave-red.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '142': {'brewery_name': 'Huntington Beach Beer Co.',
#   'type': 'Brewpub',
#   'address': '201 Main St. #E, Huntington Beach, California, 92648',
#   'website': 'http://www.hbbeerco.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '143': {'brewery_name': 'Humboldt Brewing Co.',
#   'type': 'RegionalBrewery',
#   'address': '856 10th St., Arcata, California, 95521',
#   'website': 'http://www.humboldtbrews.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '144': {'brewery_name': 'Hopyard',
#   'type': 'Brewpub',
#   'address': '470 Market Place, San Ramon, California, 94583',
#   'website': 'http://www.hopyard.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '145': {'brewery_name': 'HopTown Brewing Company',
#   'type': 'Microbrewery',
#   'address': '3015 Hopyard Rd. Suite E, Pleasanton, California, 94588',
#   'website': 'http://www.hoptownbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '146': {'brewery_name': 'Hoppy Brewing Co.',
#   'type': 'Brewpub',
#   'address': '6300 Folsom Blvd., Sacramento, California, 95819',
#   'website': 'http://www.hoppy.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '147': {'brewery_name': 'Hollywood Beach Brewing Co. ',
#   'type': 'Microbrewery',
#   'address': '4531 La Brea St., Oxnard, California, 93035',
#   'website': 'http://www.hbbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '148': {'brewery_name': 'Hollister Brewing Co',
#   'type': 'Brewpub',
#   'address': '6980 Marketplace Dr, Goleta, California, 93117',
#   'website': 'http://www.hollisterbrewco.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '149': {'brewery_name': 'Happy Valley Brewing',
#   'type': 'Microbrewery',
#   'address': '6452 Happy Valley Rd, Somerset, California, 95684',
#   'website': 'https://www.facebook.com/HappyValleyBrewery',
#   'state': 'california',
#   'state_breweries': 284},
#  '150': {'brewery_name': 'Hansa Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '649 3/4 Santa Clara Ave, Venice, California, 90291',
#   'website': 'http://www.hansabrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '151': {'brewery_name': 'Hangar 24 Craft Brewery',
#   'type': 'Microbrewery',
#   'address': '1710 Sessums Drive, Redlands, California, 92374',
#   'website': 'http://www.hangar24brewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '152': {'brewery_name': 'Half Moon Bay Brewing',
#   'type': 'Brewpub',
#   'address': 'PO Box 879, El Granada , California, 94018',
#   'website': 'http://www.hmbbrewingco.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '153': {'brewery_name': 'Green Flash Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1430 Vantage Ct. Suite 104A, Vista, California, 92083',
#   'website': 'http://www.greenflashbrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '154': {'brewery_name': 'Great Sex Brewing',
#   'type': 'ContractBrewery',
#   'address': '12763 Encanto Way, Redding, California, 96003',
#   'website': 'http://www.greatsexbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '155': {'brewery_name': 'Great Beer Company',
#   'type': 'Microbrewery',
#   'address': '21119 Superior St., Chatsworth, California, 91311',
#   'website': 'http://www.greatbeerco.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '156': {'brewery_name': 'Gordon Biersch Brewing Co. (San Jose)',
#   'type': 'Brewpub',
#   'address': '33 E. San Fernando St., San Jose, California, 95113',
#   'website': 'http://www.gordonbiersch.com/restaurants/index.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '157': {'brewery_name': 'Gordon Biersch Brewing Co. (San Jose)',
#   'type': 'RegionalBrewery',
#   'address': '357 E Taylor St, San Jose, California, 95112',
#   'website': 'http://www.gordonbiersch.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '158': {'brewery_name': 'Gordon Biersch Brewing Co. (San Francisco)',
#   'type': 'Brewpub',
#   'address': '2 Harrison St., San Francisco, California, 94105',
#   'website': 'http://www.gordonbiersch.com/restaurants/index.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '159': {'brewery_name': 'Gordon Biersch Brewing Co. (Palo Alto)',
#   'type': 'Brewpub',
#   'address': '640 Emerson St., Palo Alto, California, 94301',
#   'website': 'http://www.gordonbiersch.com/restaurants/index.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '160': {'brewery_name': 'Gordon Biersch Brewing Co.',
#   'type': 'Microbrewery-Closed',
#   'address': '24032 El Toro Rd., Laguna Hills, California',
#   'website': 'http://www.gordonbiersch.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '161': {'brewery_name': 'Gordon Biersch Brewing Co.',
#   'type': 'Brewpub',
#   'address': '5010 Mission Center Rd., San Diego, California, 92108',
#   'website': 'http://www.gordonbiersch.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '162': {'brewery_name': 'Gordon Biersch Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1623 W. Katella, Orange, California',
#   'website': 'http://www.gordonbiersch.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '163': {'brewery_name': 'Gordon Biersch Brewing Co.',
#   'type': 'Brewpub',
#   'address': '41 Hugus Alley, Pasadena, California, 91103',
#   'website': 'http://www.gordonbiersch.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '164': {'brewery_name': 'Gordon Biersch Brewing Co.',
#   'type': 'Brewpub',
#   'address': '145 S. San Fernando Rd., Burbank, California, 91502',
#   'website': 'http://www.gordonbiersch.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '165': {'brewery_name': 'Gold Hill Brewery',
#   'type': 'Microbrewery',
#   'address': '5660 Vineyard Ln., Placerville, California, 95667',
#   'website': 'http://www.goldhillvineyard.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '166': {'brewery_name': 'Gold Country Brewing',
#   'type': 'Microbrewery',
#   'address': '1170 Pinecroft Rd., Colfax, California, 95713',
#   'website': 'http://www.goldcountrybrewers.org/',
#   'state': 'california',
#   'state_breweries': 284},
#  '167': {'brewery_name': 'Full Circle Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '620 "F" St., Fresno, California, 93706',
#   'website': 'http://www.fullcirclebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '168': {'brewery_name': 'Firestone Walker Brewing Co.',
#   'type': 'Brewpub',
#   'address': '620 McMurray Rd., Buellton, California, 93427',
#   'website': 'http://www.firestonewalker.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '169': {'brewery_name': 'Firestone Walker Brewing',
#   'type': 'Microbrewery',
#   'address': '1400 Ramada Dr., Paso Robles, California, 93446',
#   'website': 'http://www.firestonebeer.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '170': {'brewery_name': 'Firehouse Grill & Brewery',
#   'type': 'Brewpub',
#   'address': '111 S. Murphy Ave., Sunnyvale, California, 94086',
#   'website': 'http://www.firehousegrill.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '171': {'brewery_name': 'Firehouse Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '7696 Miramar Rd., San Diego, California, 92126',
#   'website': 'http://www.firehousebrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '172': {'brewery_name': 'Fire House Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '1829 Arnold Way Ste. 1001, Alpine, California, 91901',
#   'website': 'http://www.firehousebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '173': {'brewery_name': 'FiftyFifty Brewing Co',
#   'type': 'Brewpub',
#   'address': '11197 Brockway Rd., Ste 1, Truckee, California, 96161',
#   'website': 'http://www.fiftyfiftybrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '174': {'brewery_name': 'Feather River Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '14665 Forest Ridge Rd. , Magalia, California, 95954',
#   'website': 'http://www.featherriverbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '175': {'brewery_name': 'Faultline Brewing Co. (Sunnyvale)',
#   'type': 'Brewpub',
#   'address': '1235 Oakmead Pkwy., Sunnyvale, California, 94086',
#   'website': 'http://www.faultlinebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '176': {'brewery_name': 'Etna Brewing Company, Inc.',
#   'type': 'Microbrewery',
#   'address': '131 Callahan St., Etna, California, 96027',
#   'website': 'http://www.etnabrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '177': {'brewery_name': 'English Ales Brewery',
#   'type': 'Brewpub',
#   'address': '223 Reindollar Ave., Marina, California, 93933',
#   'website': 'http://www.englishalesbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '178': {'brewery_name': 'Elizabeth Street Brewery',
#   'type': 'Brewpub',
#   'address': 'San Francisco, California, 94114',
#   'website': 'http://www.elizabethstreetbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '179': {'brewery_name': 'El Toro Brewpub',
#   'type': 'Brewpub',
#   'address': '17605  Monterey Dr., Morgan Hill, California, 95037',
#   'website': 'http://www.eltorobrewing.com/main.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '180': {'brewery_name': 'El Toro Brewing Company',
#   'type': 'Microbrewery',
#   'address': '17370 Hill Rd., Morgan Hill, California, 95037',
#   'website': 'http://www.eltorobrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '181': {'brewery_name': 'El Dorado Brewing Company',
#   'type': 'Microbrewery',
#   'address': '4384 Harness Tract Road, Camino, California, 95709',
#   'website': 'http://www.eldobrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '182': {'brewery_name': 'Eel River Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1777 Alamar Way, Fortuna, California, 95440',
#   'website': 'http://www.eelriverbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '183': {'brewery_name': 'Eagle Rock Brewery',
#   'type': 'Mircobrewery',
#   'address': '3056 Roswell St., Los Angeles, California, 90065',
#   'website': 'http://www.eaglerockbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '184': {'brewery_name': 'E.J. Phair Brewing Company',
#   'type': 'Microbrewery',
#   'address': '975 Detroit Ave., Unit E, Concord, California, 94520',
#   'website': 'http://www.ejphair.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '185': {'brewery_name': 'E.J. Phair Brewing Co. & Alehouse',
#   'type': 'Brewpub',
#   'address': '2151 Salvio St., Concord, California, 94518',
#   'website': 'http://www.ejphair.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '186': {'brewery_name': 'Drakes Brewing Company',
#   'type': 'Microbrewery',
#   'address': '1933 Davis Street #177 (Westgate Mall), San Leandro, California, 94577',
#   'website': 'http://www.drinkdrakes.com/home.html',
#   'state': 'california',
#   'state_breweries': 284},
#  '187': {'brewery_name': "Downtown Joe's Brewery & Restaurant",
#   'type': 'Brewpub',
#   'address': '902 Main St., Napa, California, 94559',
#   'website': 'http://www.downtownjoes.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '188': {'brewery_name': 'Downtown Brewing',
#   'type': 'Brewpub',
#   'address': '1119 Garden St., San Luis Obispo, California, 93401',
#   'website': 'http://downtownbrew.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '189': {'brewery_name': "Devil's Canyon Brewing Co.",
#   'type': 'Microbrewery',
#   'address': '111 Industrial Rd # 7, Belmount, California, 94002',
#   'website': 'http://www.devilscanyonbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '190': {'brewery_name': "Dempsey's Ale House",
#   'type': 'Brewpub',
#   'address': '50 E. Washington St., Petaluma, California, 94952',
#   'website': 'http://www.dempseys.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '191': {'brewery_name': 'Dale Bros. Brewery',
#   'type': 'Microbrewery',
#   'address': '2120 Porterfield Way, Upland, California, 91786',
#   'website': 'http://www.dalebrosbrewery.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '192': {'brewery_name': 'Creekside Brewing Co',
#   'type': 'Brewpub',
#   'address': '1040 Broad St., San Luis Obispo, California, 93401',
#   'website': 'http://www.creeksidebrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '193': {'brewery_name': 'Craftsman Brewing Company',
#   'type': 'Microbrewery',
#   'address': '1270 Lincoln Ave., Pasadena, California, 91103',
#   'website': 'http://www.craftsmanbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '194': {'brewery_name': 'Coronado Brewing Co.',
#   'type': 'Brewpub',
#   'address': '170 Orange St., Coronado, California, 92118',
#   'website': 'http://www.coronadobrewingcompany.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '195': {'brewery_name': 'Chau Tien',
#   'type': 'ContractBrewery',
#   'address': 'PO Box 221185, Carmel, California, 93923',
#   'website': 'http://www.paleale.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '196': {'brewery_name': 'Cervecerias La Cruda',
#   'type': 'Microbrewery-Closed',
#   'address': '500 4th Ave., San Diego, California',
#   'website': '                                                                            -                                                                    ',
#   'state': 'california',
#   'state_breweries': 284},
#  '197': {'brewery_name': 'Central Coast Brewing Co.',
#   'type': 'ContractBrewery',
#   'address': '1422 Monterrey St., San Luis Obispo, California, 93401',
#   'website': 'http://www.centralcoastbrewing.com/',
#   'state': 'california',
#   'state_breweries': 284},
#  '198': {'brewery_name': 'Carmel Brewing Co.',
#   'type': 'Brewpub',
#   'address': '225 Crossroads/Suite 121, Carmel, California, 93923',
# ...
#   'type': 'Brewpub',
#   'address': '417 SW 37th, Topeka, Kansas, 66611',
#   'website': 'http://www.blindtiger.com/',
#   'state': 'kansas',
#   'state_breweries': 26},
#  '939': {'brewery_name': 'Bayou State Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '5005 W. 117th St., Leawood, Kansas, 66211',
#   'website': '                                                                            -                                                                    ',
#   'state': 'kansas',
#   'state_breweries': 26},
#  '940': {'brewery_name': "Barley's",
#   'type': 'Brewpub',
#   'address': '801 S. Kansas Ave., Topeka, Kansas, 66612',
#   'website': '                                                                            -                                                                    ',
#   'state': 'kansas',
#   'state_breweries': 26},
#  '941': {'brewery_name': '23rd Street Brewery',
#   'type': 'Brewpub',
#   'address': '3512 Clinton Pkwy, Lawrence, Kansas, 66047',
#   'website': 'http://www.brew23.com/',
#   'state': 'kansas',
#   'state_breweries': 26},
#  '942': {'brewery_name': 'Silo Brewpub & Restaurant',
#   'type': 'Brewpub',
#   'address': '630 Barret Avenue, Louisville, Kentucky, 40204',
#   'website': 'http://www.grittys.com/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '943': {'brewery_name': 'Oldenberg Brewing Co.',
#   'type': 'Brewpub',
#   'address': '400 Buttermilk Pike, Fort Mitchell, Kentucky, 41017',
#   'website': 'http://realbeer.com/oldenberg/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '944': {'brewery_name': 'Oertel Brewing Company',
#   'type': 'ContractBrewery',
#   'address': '1332 Story Ave., Louisville, Kentucky, 40206',
#   'website': 'http://www.falstaffbrewing.com/falls.htm',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '945': {'brewery_name': 'Lexington Brewing Company',
#   'type': 'Microbrewery',
#   'address': '401 Cross St., Lexington, Kentucky, 40508',
#   'website': 'http://www.hempbeerco.com/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '946': {'brewery_name': "Jack Daniel's Brewery",
#   'type': 'Microbrewery',
#   'address': '4360 Brownsboro Rd., Louisville, Kentucky, 40207',
#   'website': 'http://www.jackdaniels.com/age.aspx',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '947': {'brewery_name': 'Hofbrauhaus Newport',
#   'type': 'Brewpub',
#   'address': '200 E 3rd St, Newport, Kentucky, 41071',
#   'website': 'http://www.hofbrauhausnewport.com/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '948': {'brewery_name': 'Cumberland Brews',
#   'type': 'Brewpub',
#   'address': '1576 Bardstown Rd, Louisville, Kentucky, 40205',
#   'website': 'http://www.bbcbrew.com/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '949': {'brewery_name': "Browning's Brewery at Louisville Slugger Field",
#   'type': 'Brewpub-Closed',
#   'address': '401 E Main Street, Louisville, Kentucky, 40202',
#   'website': '                                                                            -                                                                    ',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '950': {'brewery_name': 'Brownings Brewery at Louisville Slugger Field',
#   'type': 'Microbrewery-Closed',
#   'address': '401 E Main St, Louisville, Kentucky, 40202',
#   'website': '                                                                            -                                                                    ',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '951': {'brewery_name': 'Bluegrass Brewing Company',
#   'type': 'Microbrewery',
#   'address': '636 E Main St, Louisville, Kentucky, 40202',
#   'website': 'http://www.bbcbrew.com/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '952': {'brewery_name': 'Bluegrass Brewing Company',
#   'type': 'Brewpub',
#   'address': '3929 Shelbyville Rd., Louisville, Kentucky, 40207',
#   'website': 'http://www.bbcbrew.com/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '953': {'brewery_name': 'Alltechs Lexington Brewing Co',
#   'type': 'Microbrewery',
#   'address': '401 Cross St., Lexington, Kentucky, 40508',
#   'website': 'http://www.kentuckyale.com/',
#   'state': 'kentucky',
#   'state_breweries': 12},
#  '954': {'brewery_name': 'Red River Brewing Co',
#   'type': 'Microbrewery',
#   'address': 'Shreveport, Louisiana, 71106',
#   'website': 'https://www.redriverbeer.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '955': {'brewery_name': 'Pelican Brewing Co.',
#   'type': 'ContractBrewery',
#   'address': 'P.O. Box 52821, New Orleans, Louisiana, 70121',
#   'website': 'http://www.pelicanbrewery.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '956': {'brewery_name': 'Old River Brewhouse',
#   'type': 'Microbrewery-Closed',
#   'address': '708 Water St., Madisonville, Louisiana, 70447',
#   'website': '                                                                            -                                                                    ',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '957': {'brewery_name': 'New Orleans Lager and Ale Brewing',
#   'type': 'Microbrewery',
#   'address': '311 Octavia St, New Orleans, Louisiana, 70115',
#   'website': 'http://www.nolabrewing.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '958': {'brewery_name': 'New Orleans Beer Co',
#   'type': 'ContractBrewery',
#   'address': '62200 West End Blvd #3201, Slidel, Louisiana, 70461',
#   'website': 'http://www.bigeasybeer.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '959': {'brewery_name': 'Louisiana Brewing Company',
#   'type': 'Microbrewery',
#   'address': "1058 O'Neal Dr., Breaux Bridge, Louisiana, 70517",
#   'website': 'http://www.abita.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '960': {'brewery_name': 'Lafourche Brewing Company',
#   'type': 'Brewpub',
#   'address': '402 W. 3rd St., Thibodaux, Louisiana, 70301',
#   'website': '                                                                            -                                                                    ',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '961': {'brewery_name': 'Covington Brewhouse',
#   'type': 'Microbrewery',
#   'address': '226 East Lockwood Street, Covington, Louisiana, 70433',
#   'website': 'http://covingtonbrewhouse.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '962': {'brewery_name': 'Gordon Biersch Brewery Restaurant-New Orleans',
#   'type': 'Brewpub',
#   'address': '200 Poydras St, New Orleans, Louisiana, 70130',
#   'website': 'http://www.gordonbiersch.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '963': {'brewery_name': 'Dixie Brewing Co.',
#   'type': 'ContractBrewery',
#   'address': '6221 S Clairborne Ave, New Orleans, Louisiana, 70125',
#   'website': '                                                                            -                                                                    ',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '964': {'brewery_name': 'Crescent City Brewhouse',
#   'type': 'Brewpub',
#   'address': '527 Decatur St., New Orleans, Louisiana, 70130',
#   'website': 'http://www.crescentcitybrewhouse.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '965': {'brewery_name': 'Bayou Teche Brewery',
#   'type': 'Mircobrewery',
#   'address': '1106 Bushville Hwy, Arnaudville, Louisiana, 70512',
#   'website': 'http://www.bayoutechebrewing.blogspot.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '966': {'brewery_name': 'Acadian Brewing Co. LLC',
#   'type': 'Microbrewery',
#   'address': '201 N. Carrollton Ave., New Orleans, Louisiana, 70119',
#   'website': '                                                                            -                                                                    ',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '967': {'brewery_name': 'Abita Brewing Company (Pub)',
#   'type': 'Brewpub',
#   'address': '72011 Holly St., Abita Springs, Louisiana, 70420',
#   'website': 'http://www.abita.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '968': {'brewery_name': 'Abita Brewing Company (Brewery)',
#   'type': 'Microbrewery',
#   'address': '21084 Hwy. 36, Abita Springs, Louisiana, 70432',
#   'website': 'http://www.abita.com/',
#   'state': 'louisiana',
#   'state_breweries': 15},
#  '969': {'brewery_name': "Theo's Pub",
#   'type': 'Brewpub',
#   'address': 'RR #1, Box 2268, Carrabassett Valley, Maine, 4947',
#   'website': '                                                                            -                                                                    ',
#   'state': 'maine',
#   'state_breweries': 44},
#  '970': {'brewery_name': "The Moose's Tale",
#   'type': 'Brewpub',
#   'address': '1 Sunday River Rd., Bethel, Maine, 4217',
#   'website': '                                                                            -                                                                    ',
#   'state': 'maine',
#   'state_breweries': 44},
#  '971': {'brewery_name': 'Sunday River Brewing Co.',
#   'type': 'Brewpub',
#   'address': '1 Sunday River Rd., Bethel, Maine, 4217',
#   'website': 'http://www.stonecoast.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '972': {'brewery_name': 'Sugarloaf Brewing Co.',
#   'type': 'Brewpub',
#   'address': 'RR 1, Box 2268, Carrabassett Valley, Maine, 4947',
#   'website': 'http://www.somtel.com/~sugrbrew',
#   'state': 'maine',
#   'state_breweries': 44},
#  '973': {'brewery_name': 'Stone Coast Brewpub',
#   'type': 'Microbrewery',
#   'address': '23 Rice St., Portland, Maine, 4101',
#   'website': 'http://www.stonecoast.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '974': {'brewery_name': 'Sparhawk Brewers',
#   'type': 'Microbrewery-Closed',
#   'address': 'PO Box 736, South Freeport, Maine, 4078',
#   'website': '                                                                            -                                                                    ',
#   'state': 'maine',
#   'state_breweries': 44},
#  '975': {'brewery_name': 'Slopes Northern Maine Restaurant & Brewing',
#   'type': 'Brewpub-Closed',
#   'address': '150 Maysville St., Presque Isle, Maine, 4769',
#   'website': 'http://www.slopesrestaurant.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '976': {'brewery_name': 'Shipyard Brewing Company',
#   'type': 'Microbrewery',
#   'address': '86 Newbury St., Portland, Maine, 4101',
#   'website': 'http://www.shipyard.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '977': {'brewery_name': 'Sheepscot Valley Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '74 Hollywood Blvd., Whitefield, Maine, 4353',
#   'website': 'http://www.sheepscotbrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '978': {'brewery_name': 'Sebago Brewing Co & Corporate Offices',
#   'type': 'Microbrewery',
#   'address': '48 Sanford Dr., Gorham, Maine, 4038',
#   'website': 'http://www.sebagobrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '979': {'brewery_name': 'Sebago Brewing Co - South Portland',
#   'type': 'Brewpub',
#   'address': '150 Philbrook Ave/Maine Mall, South Portland, Maine, 4106',
#   'website': 'http://www.sebagobrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '980': {'brewery_name': 'Sebago Brewing Co - Gorham',
#   'type': 'Brewpub',
#   'address': '29 Elm St, Gorham, Maine, 4083',
#   'website': 'http://www.sebagobrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '981': {'brewery_name': 'Sebago Brewing Co - Downtown',
#   'type': 'Brewpub',
#   'address': '164 Middle St., Portland, Maine, 4101',
#   'website': 'http://www.sebagobrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '982': {'brewery_name': 'Sea Dog Brewing Company (Bangor)',
#   'type': 'Brewpub',
#   'address': '26 Front St., Bangor, Maine, 4401',
#   'website': 'http://www.seadogbrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '983': {'brewery_name': 'Sea Dog Brewing Company',
#   'type': 'Microbrewery',
#   'address': '43 Mechanic St., Camden, Maine, 4843',
#   'website': 'http://www.seadogbrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '984': {'brewery_name': 'Rocky Bay Brewing Co',
#   'type': 'Microbrewery',
#   'address': '230 Park St, Rockland, Maine, 4841',
#   'website': 'http://www.rockybaybrewing.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '985': {'brewery_name': 'Oak Pond Brewing Co.',
#   'type': 'Microbrewery',
#   'address': 'Oak Pond Rd. Box 1208, Skowhegan, Maine, 4976',
#   'website': 'http://www.oakpondbrewery.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '986': {'brewery_name': 'Narrow Gauge Brewing Company',
#   'type': 'Brewpub',
#   'address': '143 Pleasant Street, Farmington, Maine, 4938',
#   'website': 'http://www.byme.com/ngbgranary/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '987': {'brewery_name': 'Maine Coast Brewing Co.',
#   'type': 'Microbrewery',
#   'address': '102 Eden St., Bar Harbor, Maine, 4609',
#   'website': 'http://www.acadia.net/mcbrew/home.html',
#   'state': 'maine',
#   'state_breweries': 44},
#  '988': {'brewery_name': 'Maine Beer Co',
#   'type': 'Mircobrewery',
#   'address': '1 Industrial Way, Ste 3, Portland, Maine, 4103',
#   'website': 'http://www.mainebeercompany.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '989': {'brewery_name': 'Lompoc Cafe & Brewpub',
#   'type': 'Brewpub',
#   'address': '36 Rodick St., Bar Harbor, Maine, 4609',
#   'website': 'http://www.lompoccafe.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '990': {'brewery_name': 'Liberal Cup Public House and Brewery',
#   'type': 'Brewpub',
#   'address': '115 Water St, Hallowell, Maine, 4347',
#   'website': 'http://www.theliberalcup.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '991': {'brewery_name': 'Lake St. George Brewing Co.',
#   'type': 'Microbrewery',
#   'address': 'RR #1, Box 2505, Liberty, Maine, 4949',
#   'website': '                                                                            -                                                                    ',
#   'state': 'maine',
#   'state_breweries': 44},
#  '992': {'brewery_name': 'Kennebunk Port Brewing Co.',
#   'type': 'Microbrewery-Closed',
#   'address': '86 Newbury St., Portland, Maine, 4101',
#   'website': '                                                                            -                                                                    ',
#   'state': 'maine',
#   'state_breweries': 44},
#  '993': {'brewery_name': 'Kennebec River Brewery',
#   'type': 'Brewpub',
#   'address': 'RT 201, The Forks, Maine, 4985',
#   'website': 'http://www.northernoutdoors.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '994': {'brewery_name': 'Kennebec Brewing Co',
#   'type': 'Microbrewery',
#   'address': '627 Water St., Gardiner, Maine, 4345',
#   'website': '                                                                            -                                                                    ',
#   'state': 'maine',
#   'state_breweries': 44},
#  '995': {'brewery_name': 'Growstown Brewery',
#   'type': 'Microbrewery',
#   'address': '354 Church Road, Brunswick, Maine, 4011',
#   'website': 'http://www.growstownbrew.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '996': {'brewery_name': "Gritty McDuff's Brew Pub (#2)",
#   'type': 'Brewpub',
#   'address': '187 Lower Main St., Freeport, Maine, 4032',
#   'website': 'http://www.grittys.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '997': {'brewery_name': "Gritty McDuff's Brew Pub (#1)",
#   'type': 'Brewpub',
#   'address': '369 Fore St., Portland, Maine, 4101',
#   'website': 'http://www.grittys.com/',
#   'state': 'maine',
#   'state_breweries': 44},
#  '998': {'brewery_name': 'Gritty McDuffs - Lwiston/Auburn',
#   'type': 'Brewpub',
#   'address': '68 Main St, Auburn, Maine, 4210',
#   'website': 'http://www.grittys.com/aug08/LA_event2.pdf',
#   'state': 'maine',
#   'state_breweries': 44},
#  '999': {'brewery_name': 'Great Falls Brewing Co.',
#   'type': 'Brewpub',
#   'address': '36 Court St., Auburn, Maine, 4210',
#   'website': '                                                                            -                                                                    ',
#   'state': 'maine',
#   'state_breweries': 44},
#  ...}

# %%
# so example: https://www.google.com/search?client=firefox-b-d&q=pandas+string+column+in
brew[brew["address"].str.lower().str.contains("plaza")]
# Out:
#                                     brewery_name            type  \
# 59                            River City Brewing         Brewpub
# 362                    Upstream Brewing Co. (#2)         Brewpub
# 584   C.B. and Potts/Big Horn Brewery- Englewood         Brewpub
# 599                             Big Horn Brewery         Brewpub
# 663                    Key West Overseas Brewery    Microbrewery
# 895                      New Albanian Brewing Co         Brewpub
# 1065             Rock Bottom Brewery - Braintree  Brewpub-Closed
# 1177                          Hideout Brewing Co    Microbrewery
# 1232           Rock Bottom Brewery (Minneapolis)         Brewpub
# 1323                 Kroghs Restaurant & Brewpub         Brewpub
# 1442       John Harvards Brew House - Lake Grove         Brewpub
# 1464                         Defiant Brewing Co.    Microbrewery
# 1469                    Commonwealth Brewing Co.  Brewpub-Closed
# 2008                    Panther City Brewing Co.         Brewpub
# 2121    Sweetwater Tavern & Brewery - Merrifield         Brewpub
# 2122                 Sweetwater Tavern & Brewery         Brewpub
# 2405                      Isla Verde Brewing Co.    Microbrewery
#
#                                                 address  \
# 59    545 Downtown Plaza, Ste. 1115 , Sacramento, Ca...
# 362          17070 Wright Plaza, Omaha, Nebraska, 68130
# 584   6575 Greenwood Plaza Blvd., Englewood, Colorad...
# 599   6575 Greenwood Plaza Blvd., Englewood, Colorad...
# 663            1107 Key Plaza, Key West, Florida, 33040
# 895          3312 Plaza Dr., New Albany, Indiana, 47150
# 1065  South Shore Plaza, Braintree, Massachusetts, 2184
# 1177  3113 Plaza Drive NE, Grand Rapids, Michigan, 4...
# 1232  800 La Salle Plaza , Minneapolis, Minnesota, 5...
# 1323      23 White Deer Plaza, Sparta, New Jersey, 7871
# 1442  2093 Smith Haven Plaza, Lake Grove, New York, ...
# 1464     6 E Dexter Plaza, Pearl River, New York, 10965
# 1469  10 Rockefeller Plaza (@48th St.), New York, Ne...
# 2008         2513 Rodeo Plaza, Fort Worth, Texas, 76106
# 2121  3066 Gatehouse Plaza, Falls Church, Virginia, ...
# 2122   45980 Waterview Plaza, Sterling, Virginia, 20166
# 2405  Condiminum Torrimar Plaza # 14B, Guaynabo , PR...
#
#                                                 website          state  \
# 59                     http://www.rivercitybrewing.net/     california
# 362                     http://www.upstreambrewing.com/       nebraska
# 584                             http://www.cbpotts.com/       colorado
# 599                              http://www.theram.com/       colorado
# 663                                                 ...        florida
# 895                              http://www.richos.com/        indiana
# 1065                         http://www.rockbottom.com/  massachusetts
# 1177                     http://www.hideoutbrewing.com/       michigan
# 1232                         http://www.rockbottom.com/      minnesota
# 1323                             http://www.kroghs.com/     new-jersey
# 1442                       http://www.johnharvards.com/       new-york
# 1464                     http://www.defiantbrewing.com/       new-york
# 1469                                                ...       new-york
# 2008                                                ...          texas
# 2121           http://www.greatamericanrestaurants.com/       virginia
# 2122           http://www.greatamericanrestaurants.com/       virginia
# 2405                                                ...    puerto-rico
#
#       state_breweries
# 59                284
# 362                15
# 584               182
# 599               182
# 663                99
# 895                31
# 1065               71
# 1177               94
# 1232               40
# 1323               41
# 1442              107
# 1464              107
# 1469              107
# 2008               90
# 2121               43
# 2122               43
# 2405                3

# %% [markdown]
# Otros:
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.json.json_normalize.html
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html

# %%
df = pd.read_csv("all_annotated.tsv", sep="\t")
df["Country"].value_counts().plot();

# %%
url_base = 'https://raw.githubusercontent.com/cmrivers/ebola/master/guinea_data/'

# %%
pd.read_csv(url_base + "2014-09-02.csv").columns
# Out:
# Index(['Date', 'Description', 'Totals', 'Conakry', 'Gueckedou', 'Macenta',
#        'Dabola', 'Kissidougou', 'Dinguiraye', 'Telimele', 'Boffa', 'Kouroussa',
#        'Siguiri', 'Pita', 'Mzerekore', 'Yomou', 'Dubreka', 'Forecariah',
#        'Kerouane', 'Coyah', 'Dalaba', 'Beyla', 'Kindia', 'Lola'],
#       dtype='object')

# %% [markdown]
# ### Airports

# %% [markdown]
# Más info y fuentes:
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼
# * 👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼👉🏼 https://pandas.pydata.org/pandas-docs/stable/ 👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼👈🏼

# %% [markdown]
# Datos para practicas, explorar:
# * https://data.world/
# * https://www.kaggle.com/
# * https://archive.ics.uci.edu/

# %% [markdown]
# Ricardo Ander-Egg Aguilar
#
# * 🖥: https://ricardoanderegg.com/
# * 🐦: https://twitter.com/ricardoanderegg
# * 👨🏻‍🎓: https://www.linkedin.com/in/ricardoanderegg/
